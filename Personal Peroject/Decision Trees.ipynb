# %% [markdown]
# # Practicing Decision Trees

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../input/iris/Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                count       mean        std  min    25%    50%     75%    max
# Id             150.0  75.500000  43.445368  1.0  38.25  75.50  112.75  150.0
# SepalLengthCm  150.0   5.843333   0.828066  4.3   5.10   5.80    6.40    7.9
# SepalWidthCm   150.0   3.054000   0.433594  2.0   2.80   3.00    3.30    4.4
# PetalLengthCm  150.0   3.758667   1.764420  1.0   1.60   4.35    5.10    6.9
# PetalWidthCm   150.0   1.198667   0.763161  0.1   0.30   1.30    1.80    2.5

# %% [markdown]
# ### Define Predictor and Target Variables

# %%
X = df[['SepalLengthCm', 'SepalWidthCm',
        'PetalLengthCm', 'PetalWidthCm']]
y = df['Species']

# %% [markdown]
# ### Import Decision Tree Classifier and Fit into Dataset

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

dtree = DecisionTreeClassifier(criterion= 'gini', max_depth= 2,min_samples_leaf= 1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state=42)

# %%
y_train = np.array(y_train).reshape(-1, 1)
y_train.shape
# Out:
# (100, 1)

# %%
y_test = np.array(y_test).reshape(-1, 1)
y_test.shape
# Out:
# (50, 1)

# %% [markdown]
# ### Fit Decision Tree Model

# %%
dtree_train = dtree.fit(X_train, y_train)
dtree_pred = dtree_train.predict(X_test)

# %% [markdown]
# ### Evaluate Model

# %%
from sklearn.metrics import classification_report
print(classification_report(dtree_pred, y_test))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        19
# Iris-versicolor       1.00      0.94      0.97        16
#  Iris-virginica       0.94      1.00      0.97        15
#
#        accuracy                           0.98        50
#       macro avg       0.98      0.98      0.98        50
#    weighted avg       0.98      0.98      0.98        50

# %% [markdown]
# ### Visualize the Tree

# %%
fig1 = plt.figure(figsize=(16,10))
tree.plot_tree(dtree_pred, filled=True, 
              feature_names=X.columns, fontsize=8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_18/2593186088.py in <module>
#       1 fig1 = plt.figure(figsize=(16,10))
#       2 tree.plot_tree(dtree_pred, filled=True,
# ----> 3               feature_names=X.columns, fontsize=8)
#
# /opt/conda/lib/python3.7/site-packages/sklearn/tree/_export.py in plot_tree(decision_tree, max_depth, feature_names, class_names, label, filled, impurity, node_ids, proportion, rounded, precision, ax, fontsize)
#     178     """
#     179
# --> 180     check_is_fitted(decision_tree)
#     181
#     182     exporter = _MPLTreeExporter(
#
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1206
#    1207     if not hasattr(estimator, "fit"):
# -> 1208         raise TypeError("%s is not an estimator instance." % (estimator))
#    1209
#    1210     if attributes is not None:
#
# TypeError: ['Iris-versicolor' 'Iris-setosa' 'Iris-virginica' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-setosa' 'Iris-versicolor' 'Iris-virginica'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-versicolor'
#  'Iris-virginica' 'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica'
#  'Iris-setosa' 'Iris-virginica' 'Iris-setosa' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-versicolor'
#  'Iris-setosa' 'Iris-setosa' 'Iris-virginica' 'Iris-versicolor'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-virginica'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-setosa' 'Iris-setosa'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica' 'Iris-versicolor'
#  'Iris-virginica'] is not an estimator instance.

# %% [markdown]
# # Decision Trees with Hyperparameter Tuning

# %% [markdown]
# ### Defining X and y Variables

# %%
X = df[['SepalLengthCm', 'SepalWidthCm',
        'PetalLengthCm', 'PetalWidthCm']]
y = df['Species']

# %% [markdown]
# ### Import Grid Search

# %%
from sklearn.model_selection import GridSearchCV
clf = GridSearchCV(DecisionTreeClassifier(), {
    'max_depth': [1, 2],
    'criterion': ['gini', 'entropy'],
    'min_samples_leaf': [1, 2]
}, cv = 5)

clf.fit(X, y)
clf.cv_results_
df = pd.DataFrame(clf.cv_results_)
df
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.002113      0.000471         0.001363        0.000291
# 1       0.001587      0.000044         0.001110        0.000021
# 2       0.001667      0.000117         0.001124        0.000017
# 3       0.001643      0.000080         0.001133        0.000030
# 4       0.001722      0.000126         0.001174        0.000059
# 5       0.001577      0.000056         0.001115        0.000014
# 6       0.001667      0.000037         0.001137        0.000012
# 7       0.001639      0.000068         0.001138        0.000056
#
#   param_criterion param_max_depth param_min_samples_leaf  \
# 0            gini               1                      1
# 1            gini               1                      2
# 2            gini               2                      1
# 3            gini               2                      2
# 4         entropy               1                      1
# 5         entropy               1                      2
# 6         entropy               2                      1
# 7         entropy               2                      2
#
#                                               params  split0_test_score  \
# 0  {'criterion': 'gini', 'max_depth': 1, 'min_sam...           0.666667
# 1  {'criterion': 'gini', 'max_depth': 1, 'min_sam...           0.666667
# 2  {'criterion': 'gini', 'max_depth': 2, 'min_sam...           0.933333
# 3  {'criterion': 'gini', 'max_depth': 2, 'min_sam...           0.933333
# 4  {'criterion': 'entropy', 'max_depth': 1, 'min_...           0.666667
# 5  {'criterion': 'entropy', 'max_depth': 1, 'min_...           0.666667
# 6  {'criterion': 'entropy', 'max_depth': 2, 'min_...           0.933333
# 7  {'criterion': 'entropy', 'max_depth': 2, 'min_...           0.933333
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.666667           0.666667           0.666667           0.666667
# 1           0.666667           0.666667           0.666667           0.666667
# 2           0.966667           0.900000           0.866667           1.000000
# 3           0.966667           0.900000           0.866667           1.000000
# 4           0.666667           0.666667           0.666667           0.666667
# 5           0.666667           0.666667           0.666667           0.666667
# 6           0.966667           0.900000           0.866667           1.000000
# 7           0.966667           0.900000           0.866667           1.000000
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.666667         0.00000                5
# 1         0.666667         0.00000                5
# 2         0.933333         0.04714                1
# 3         0.933333         0.04714                1
# 4         0.666667         0.00000                5
# 5         0.666667         0.00000                5
# 6         0.933333         0.04714                1
# 7         0.933333         0.04714                1

# %% [markdown]
# ### Look at Best Combination and the Score

# %%
clf.best_score_
# Out:
# 0.9333333333333332

# %%
clf.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 1}

# %%
DecisionTreeClassifier().get_params().keys()
# Out:
# dict_keys(['ccp_alpha', 'class_weight', 'criterion', 'max_depth', 'max_features', 'max_leaf_nodes', 'min_impurity_decrease', 'min_samples_leaf', 'min_samples_split', 'min_weight_fraction_leaf', 'random_state', 'splitter'])
